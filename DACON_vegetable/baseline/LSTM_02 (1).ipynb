# %%
import glob
import os
from tqdm import tqdm

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras import layers, models, optimizers

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=2, verbose=1)

# %%
# gpu 설정
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
plt.rcParams["font.family"] = 'NanumGothic'
data = pd.read_csv(os.path.join('Data', 'public_data', 'train.csv'))

# %%
# 평가식
def nmae(y_true, y_pred):
    score = np.mean(np.abs(y_true - y_pred) / y_true)
    return score

# %%
# 정규화
def normalize(data, col):
    
    # 요일은 원핫 인코딩을 적용함, 요일에 대한 의미가 없을 것이라고 판단
    data = pd.concat([data, pd.get_dummies(data['요일'])], axis = 1)
    data = data.drop(['요일'], axis = 1)

    col1 = data.columns[-7:].to_list()
    col2 = data.columns[1:-7].to_list()

    new_col = ['date'] + col1 + col2
    data = data[new_col]
    data = data.drop(['date'], axis = 1)
    # 0 ~ 1 값으로 정규화 진행
    norm = data.iloc[:,8:].max(0)
    data.iloc[:,8:] = data.iloc[:,8:]/norm
    
    train = data.iloc[:, col:col + 2]
    
    return train, norm

# %%
# train & test 분리
def load_data(data, window_size = 28, future_size = 28, train_size = 0.9):
        x = []; y = []
        for i in range(len(data) - window_size - future_size):
            x.append(data.iloc[i: i+window_size])
            y.append(data.iloc[i+window_size:i+window_size+future_size, 1]) # 가격만

        x = np.array(x)
        y = np.array(y)

        train_idx = round(len(x) * train_size)

        train_x = x[:train_idx]
        train_y = y[:train_idx]

        valid_x = x[train_idx:]
        valid_y = y[train_idx:]
        
        return train_x, train_y, valid_x, valid_y

# %%
# 모델 구축
def build_model():
    # Build the LSTM model
    # return_sequences 이전 정보를 모두 볼지 안볼지 확인하는 옵션
    model = Sequential()
    model.add(LSTM(28, return_sequences = True, input_shape = (train_x.shape[1], 2)))
    model.add(LSTM(100, return_sequences = False))
    model.add(Dense(50))
    model.add(Dense(28, activation = "linear"))

    model.compile(loss='mse', optimizer='adam')
    return model

# %%
window_size = 28
submission = pd.read_csv('Data/sample_submission.csv')
public_date_list = submission[submission['예측대상일자'].str.contains('2020')]['예측대상일자'].str.split('+').str[0].unique()

# %%
for n, col in enumerate(list(range(7, 49, 2))):

    data = pd.read_csv('Data/public_data/train.csv')
    train, norm = normalize(data, col)
    
    train_x, train_y, valid_x, valid_y = load_data(train)
    
    
    model = build_model()
    model.fit(train_x, train_y, batch_size=1, epochs=200, validation_data=(valid_x, valid_y), verbose=1, callbacks = [early_stop])
    
    y_pred = model.predict(valid_x)
    y_true = valid_y

    
    target_idx = np.where(y_true != 0)
    y_pred = y_pred[target_idx]
    y_true = y_true[target_idx]
    
    print(train.columns[1], '의 NMAE: ', nmae(y_true, y_pred))
    
    ## 실제 test데이터 생성
    for date in public_date_list:
        test_df = pd.read_csv(f'Data/public_data/test_files/test_{date}.csv')
        data = pd.read_csv('Data/public_data/train.csv')
        data = pd.concat([data, test_df]).iloc[-window_size:]

        test, norm = normalize(data, col)
        sub_output = model.predict(test.to_numpy().reshape(1,28,2)) * norm[n*2]

        idx = submission[submission['예측대상일자'].str.contains(date)].index
        submission.loc[idx, train.columns[1]] = sub_output[0,[6,13,27]]
    print(submission.iloc[:20,n+1])
# Out:
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0059 - val_loss: 0.0085
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0054 - val_loss: 0.0094
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0051 - val_loss: 0.0090
# Epoch 00003: early stopping
# 배추_가격(원/kg) 의 NMAE:  0.35132294555570365
# 0     390.230957
# 1     364.403931
# 2     342.680389
# 3     390.140594
# 4     364.481262
# 5     342.919434
# 6     390.053345
# 7     364.523590
# 8     342.902649
# 9      67.691467
# 10     35.171719
# 11     39.881962
# 12    306.579102
# 13    241.803589
# 14    269.923096
# 15    217.988983
# 16    166.067825
# 17    200.219604
# 18    270.015747
# 19    220.488174
# Name: 배추_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0420 - val_loss: 0.0277
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0363 - val_loss: 0.0234
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0315 - val_loss: 0.0215
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0300 - val_loss: 0.0202
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0248 - val_loss: 0.0152
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0194 - val_loss: 0.0123
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0166 - val_loss: 0.0118
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0161 - val_loss: 0.0112
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0158 - val_loss: 0.0107
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0155 - val_loss: 0.0113
# Epoch 11/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0151 - val_loss: 0.0109
# Epoch 00011: early stopping
# 무_가격(원/kg) 의 NMAE:  0.2069515750714774
# 0      526.810974
# 1      747.890686
# 2      715.576111
# 3      868.790955
# 4     1095.748901
# 5      947.009827
# 6      779.213928
# 7      980.929138
# 8      689.042969
# 9      810.976135
# 10    1001.792480
# 11     685.502197
# 12     930.614136
# 13    1094.778198
# 14     768.722961
# 15    1064.993286
# 16    1165.519653
# 17     776.695923
# 18    -145.499283
# 19     -84.797348
# Name: 무_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0262 - val_loss: 0.0199
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0212 - val_loss: 0.0149
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0178 - val_loss: 0.0127
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0120 - val_loss: 0.0068
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0079 - val_loss: 0.0061
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0076 - val_loss: 0.0062
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0073 - val_loss: 0.0057
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0072 - val_loss: 0.0063
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 00009: early stopping
# 양파_가격(원/kg) 의 NMAE:  0.12608720192602796
# 0     631.129883
# 1     582.398682
# 2     593.250000
# 3     654.249512
# 4     655.594482
# 5     585.054993
# 6     758.477905
# 7     729.867798
# 8     618.648071
# 9     726.042114
# 10    719.667969
# 11    591.238770
# 12    744.634338
# 13    766.710571
# 14    671.739685
# 15    722.184692
# 16    728.285095
# 17    677.307068
# 18   -204.306915
# 19   -178.871262
# Name: 양파_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 00005: early stopping
# 건고추_가격(원/kg) 의 NMAE:  0.3724818053357922
# 0     3848.074219
# 1     3848.877930
# 2     4945.966309
# 3     4147.734863
# 4     4084.541016
# 5     5284.254395
# 6     3452.113037
# 7     3206.957275
# 8     4044.239746
# 9     2349.153076
# 10    1587.463135
# 11    1754.704712
# 12    2689.596924
# 13    1345.330444
# 14    1530.880981
# 15    3562.955078
# 16    1837.512573
# 17    2353.652100
# 18    4203.414551
# 19    2360.171875
# Name: 건고추_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0666 - val_loss: 0.0458
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0508 - val_loss: 0.0262
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0236 - val_loss: 0.0145
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0154 - val_loss: 0.0084
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0138 - val_loss: 0.0099
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0134 - val_loss: 0.0106
# Epoch 00006: early stopping
# 마늘_가격(원/kg) 의 NMAE:  0.16272457565964416
# 0     4546.910156
# 1     5370.061523
# 2     5339.697754
# 3     4355.702148
# 4     4864.045410
# 5     4887.999512
# 6     4516.371094
# 7     5397.347656
# 8     4782.642578
# 9     4608.404297
# 10    5260.021484
# 11    4889.340820
# 12    5344.952148
# 13    5819.205078
# 14    5688.727051
# 15    4883.462402
# 16    5215.436035
# 17    5072.712891
# 18    1869.311157
# 19    1940.022461
# Name: 마늘_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0337 - val_loss: 0.0355
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0298 - val_loss: 0.0266
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0256 - val_loss: 0.0268
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0223 - val_loss: 0.0182
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0168 - val_loss: 0.0138
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0125 - val_loss: 0.0127
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0122 - val_loss: 0.0142
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0116 - val_loss: 0.0132
# Epoch 00008: early stopping
# 대파_가격(원/kg) 의 NMAE:  0.16528443097511467
# 0     1825.984253
# 1     1613.535889
# 2     1349.367798
# 3     1869.893311
# 4     1578.052490
# 5     1296.961060
# 6     1734.888184
# 7     1405.659302
# 8     1278.256226
# 9     1539.751709
# 10    1364.464355
# 11    1172.474854
# 12    1777.595703
# 13    1527.316040
# 14    1344.975586
# 15    2106.765625
# 16    1813.819458
# 17    1490.138428
# 18     618.534851
# 19     304.925201
# Name: 대파_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0266 - val_loss: 0.0411
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0235 - val_loss: 0.0328
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0202 - val_loss: 0.0314
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0169 - val_loss: 0.0266
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0138 - val_loss: 0.0183
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0105 - val_loss: 0.0153
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0101 - val_loss: 0.0153
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0097 - val_loss: 0.0179
# Epoch 00008: early stopping
# 얼갈이배추_가격(원/kg) 의 NMAE:  0.2001428830533236
# 0     953.710022
# 1     924.436462
# 2     758.278259
# 3     941.699280
# 4     922.081299
# 5     764.645569
# 6     644.046692
# 7     595.155212
# 8     465.741180
# 9     486.020966
# 10    494.469116
# 11    415.451294
# 12    634.446716
# 13    709.426331
# 14    672.532837
# 15    514.508789
# 16    551.215271
# 17    512.889893
# 18    240.059326
# 19    296.921082
# Name: 얼갈이배추_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0340 - val_loss: 0.0532
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0305 - val_loss: 0.0476
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0269 - val_loss: 0.0433
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0261 - val_loss: 0.0418
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0230 - val_loss: 0.0326
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0202 - val_loss: 0.0279
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0166 - val_loss: 0.0234
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0148 - val_loss: 0.0222
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0143 - val_loss: 0.0230
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0139 - val_loss: 0.0286
# Epoch 00010: early stopping
# 양배추_가격(원/kg) 의 NMAE:  0.31144444384304054
# 0     667.464661
# 1     595.618408
# 2     521.538025
# 3     767.465576
# 4     675.718506
# 5     582.270020
# 6     693.049683
# 7     574.401001
# 8     523.654785
# 9     508.424591
# 10    423.436066
# 11    433.588898
# 12    608.155701
# 13    527.474670
# 14    532.179382
# 15    458.848694
# 16    421.334503
# 17    467.721588
# 18    139.583496
# 19     67.821556
# Name: 양배추_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0325 - val_loss: 0.0375
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0294 - val_loss: 0.0392
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0258 - val_loss: 0.0334
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0239 - val_loss: 0.0287
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0206 - val_loss: 0.0247
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0184 - val_loss: 0.0263
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0166 - val_loss: 0.0198
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0152 - val_loss: 0.0192
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0149 - val_loss: 0.0197
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0145 - val_loss: 0.0203
# Epoch 00010: early stopping
# 깻잎_가격(원/kg) 의 NMAE:  0.21735890576374264
# 0     4931.467773
# 1     4934.265625
# 2     4993.927246
# 3     4441.870117
# 4     4643.827637
# 5     4502.436035
# 6     3479.239990
# 7     3535.990967
# 8     3516.981934
# 9     3930.993164
# 10    4105.191406
# 11    3953.310059
# 12    5089.709961
# 13    5447.584961
# 14    5074.403809
# 15    4101.072754
# 16    4596.875000
# 17    4179.097656
# 18     157.697571
# 19     -48.961304
# Name: 깻잎_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0135 - val_loss: 0.0165
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0105 - val_loss: 0.0214
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0098 - val_loss: 0.0219
# Epoch 00003: early stopping
# 시금치_가격(원/kg) 의 NMAE:  0.27626986812771304
# 0     3220.229004
# 1     2782.148926
# 2     1562.539307
# 3     2897.667480
# 4     2498.065430
# 5     1442.090210
# 6     2586.750732
# 7     2212.680664
# 8     1313.975342
# 9     2286.465088
# 10    1906.861328
# 11    1154.709839
# 12    2012.394043
# 13    1634.134521
# 14    1021.807129
# 15    1787.429443
# 16    1417.232178
# 17     923.964478
# 18    1557.786499
# 19    1220.850220
# Name: 시금치_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0287 - val_loss: 0.0189
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0249 - val_loss: 0.0185
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0230 - val_loss: 0.0156
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0212 - val_loss: 0.0163
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0204 - val_loss: 0.0159
# Epoch 00005: early stopping
# 미나리_가격(원/kg) 의 NMAE:  0.34160230339588193
# 0     3442.105713
# 1     3522.416992
# 2     2793.358643
# 3     4219.849609
# 4     4093.855713
# 5     3239.416504
# 6     2043.391602
# 7     1822.035767
# 8     1287.281860
# 9      761.475159
# 10     809.121582
# 11     555.881470
# 12     759.052307
# 13    1032.895020
# 14    1001.125061
# 15     715.529480
# 16    1033.128540
# 17    1182.916504
# 18     849.990417
# 19    1221.445801
# Name: 미나리_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0137 - val_loss: 0.0160
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0109 - val_loss: 0.0118
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0094 - val_loss: 0.0081
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0063 - val_loss: 0.0027
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0042 - val_loss: 0.0028
# Epoch 00006: early stopping
# 당근_가격(원/kg) 의 NMAE:  0.11354765815788985
# 0     1309.033203
# 1     1332.410156
# 2     1177.326904
# 3     1319.733521
# 4     1384.297729
# 5     1276.215210
# 6     1113.370483
# 7     1185.688843
# 8     1087.536011
# 9     1037.016235
# 10    1106.828369
# 11    1010.462463
# 12    1098.810059
# 13    1133.671631
# 14     969.738037
# 15     949.815125
# 16     919.334412
# 17     798.844299
# 18     684.747986
# 19     625.839722
# Name: 당근_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0170 - val_loss: 0.0138
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0150 - val_loss: 0.0113
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0131 - val_loss: 0.0116
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0106 - val_loss: 0.0085
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0078 - val_loss: 0.0078
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0074 - val_loss: 0.0081
# Epoch 11/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 12/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 13/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0070 - val_loss: 0.0070
# Epoch 00013: early stopping
# 파프리카_가격(원/kg) 의 NMAE:  0.22179749768012524
# 0     3552.940918
# 1     3461.895508
# 2     3039.084961
# 3     2133.965820
# 4     2170.050781
# 5     2257.835205
# 6     2622.471436
# 7     2710.052734
# 8     2315.930908
# 9     2720.666992
# 10    3001.224365
# 11    2260.336426
# 12    2897.417969
# 13    3563.589111
# 14    3105.720703
# 15    1220.177612
# 16    2152.677002
# 17    1726.452515
# 18     166.803665
# 19    1586.193604
# Name: 파프리카_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0494 - val_loss: 0.0351
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0388 - val_loss: 0.0184
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0218 - val_loss: 0.0059
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0162 - val_loss: 0.0049
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0154 - val_loss: 0.0045
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0149 - val_loss: 0.0050
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0148 - val_loss: 0.0039
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0145 - val_loss: 0.0039
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0142 - val_loss: 0.0050
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0139 - val_loss: 0.0034
# Epoch 11/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0134 - val_loss: 0.0039
# Epoch 12/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0131 - val_loss: 0.0037
# Epoch 00012: early stopping
# 새송이_가격(원/kg) 의 NMAE:  0.10236282236306561
# 0     1703.947266
# 1     1837.264648
# 2     1950.623047
# 3     1715.614136
# 4     1878.565063
# 5     2017.002808
# 6     1890.024292
# 7     1742.839966
# 8     1798.671753
# 9     1831.972900
# 10    1710.244019
# 11    1778.502563
# 12    2272.988037
# 13    2068.642090
# 14    2047.659424
# 15    1959.421509
# 16    2050.801514
# 17    2021.596436
# 18    -242.365540
# 19    -277.491882
# Name: 새송이_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0409 - val_loss: 0.0207
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0336 - val_loss: 0.0178
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0296 - val_loss: 0.0135
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0223 - val_loss: 0.0096
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0161 - val_loss: 0.0070
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0156 - val_loss: 0.0071
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0149 - val_loss: 0.0072
# Epoch 00007: early stopping
# 팽이버섯_가격(원/kg) 의 NMAE:  0.21617142050533206
# 0     2079.491699
# 1     1957.802490
# 2     1831.388672
# 3     2122.352051
# 4     2017.009155
# 5     1888.947266
# 6     1738.930176
# 7     1672.158203
# 8     1507.063354
# 9     1561.351074
# 10    1604.481567
# 11    1511.586548
# 12    1250.751709
# 13    1224.234985
# 14    1295.129272
# 15    1242.468994
# 16    1203.172241
# 17    1483.062866
# 18     101.362167
# 19      54.818275
# Name: 팽이버섯_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0183 - val_loss: 0.0245
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0169 - val_loss: 0.0212
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0141 - val_loss: 0.0193
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0132 - val_loss: 0.0191
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0110 - val_loss: 0.0155
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0097 - val_loss: 0.0139
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0075 - val_loss: 0.0104
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0067 - val_loss: 0.0102
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0065 - val_loss: 0.0125
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0063 - val_loss: 0.0097
# Epoch 11/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0060 - val_loss: 0.0111
# Epoch 12/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0060 - val_loss: 0.0084
# Epoch 13/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0057 - val_loss: 0.0096
# Epoch 14/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0056 - val_loss: 0.0084
# Epoch 00014: early stopping
# 토마토_가격(원/kg) 의 NMAE:  0.2140383140533475
# 0     2355.599121
# 1     2457.753662
# 2     3741.208984
# 3      526.637146
# 4     1753.656250
# 5     3152.379150
# 6     -722.879456
# 7      701.223022
# 8     1901.439209
# 9     1072.393066
# 10    3099.022217
# 11    4328.188965
# 12    1494.647339
# 13    3742.889893
# 14    4915.580078
# 15    2116.164307
# 16    2182.992432
# 17    2177.046387
# 18    2469.546387
# 19    2783.493164
# Name: 토마토_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0156 - val_loss: 0.0261
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0144 - val_loss: 0.0238
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0139 - val_loss: 0.0239
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0134 - val_loss: 0.0217
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0129 - val_loss: 0.0192
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0123 - val_loss: 0.0194
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0115 - val_loss: 0.0174
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0113 - val_loss: 0.0187
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0109 - val_loss: 0.0157
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0105 - val_loss: 0.0166
# Epoch 11/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0099 - val_loss: 0.0181
# Epoch 00011: early stopping
# 청상추_가격(원/kg) 의 NMAE:  0.4334219934004444
# 0     2645.181152
# 1     2184.726807
# 2     1896.309692
# 3     2006.473633
# 4     1883.904175
# 5     1597.961182
# 6      969.480164
# 7     1242.835205
# 8      903.411499
# 9      116.999123
# 10     464.643341
# 11     299.093109
# 12     857.498779
# 13     896.124146
# 14     698.843506
# 15    3112.206787
# 16    2471.708252
# 17    1546.597656
# 18     518.872192
# 19     312.693207
# Name: 청상추_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0280 - val_loss: 0.0261
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0257 - val_loss: 0.0188
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0217 - val_loss: 0.0192
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0197 - val_loss: 0.0141
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0158 - val_loss: 0.0107
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0125 - val_loss: 0.0105
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0114 - val_loss: 0.0098
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0112 - val_loss: 0.0084
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0111 - val_loss: 0.0113
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0110 - val_loss: 0.0093
# Epoch 00010: early stopping
# 백다다기_가격(원/kg) 의 NMAE:  0.209163148263109
# 0     668.601929
# 1     794.578552
# 2     780.351074
# 3     755.671631
# 4     848.561768
# 5     886.601501
# 6     703.265625
# 7     794.091858
# 8     865.340271
# 9     231.943832
# 10    321.447266
# 11    430.825531
# 12    550.530823
# 13    633.800232
# 14    769.979370
# 15    649.846252
# 16    727.313171
# 17    967.597595
# 18    820.441162
# 19    786.626160
# Name: 백다다기_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0185 - val_loss: 0.0284
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0158 - val_loss: 0.0228
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0140 - val_loss: 0.0219
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0132 - val_loss: 0.0197
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0113 - val_loss: 0.0184
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0100 - val_loss: 0.0182
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0089 - val_loss: 0.0158
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0084 - val_loss: 0.0165
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0082 - val_loss: 0.0161
# Epoch 00009: early stopping
# 애호박_가격(원/kg) 의 NMAE:  0.24733178037715617
# 0      625.835449
# 1      589.242493
# 2      557.865295
# 3      699.518616
# 4      662.040649
# 5      724.324341
# 6      401.927460
# 7      388.613068
# 8      503.718597
# 9      137.729507
# 10     214.355713
# 11     219.783966
# 12     735.790527
# 13     756.498413
# 14     643.461914
# 15    1029.107544
# 16     806.583984
# 17     966.665222
# 18     -20.101923
# 19    -149.187256
# Name: 애호박_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0069 - val_loss: 0.0078
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0065 - val_loss: 0.0076
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0060 - val_loss: 0.0078
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0057 - val_loss: 0.0070
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 11/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 12/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 00012: early stopping
# 캠벨얼리_가격(원/kg) 의 NMAE:  0.23981474462957775
# 0     808.666138
# 1     630.522705
# 2     440.841919
# 3     815.783630
# 4     644.483154
# 5     447.463379
# 6     830.111816
# 7     637.933777
# 8     427.350708
# 9     435.823914
# 10    319.255615
# 11    206.254288
# 12    534.227051
# 13    415.478577
# 14    350.658875
# 15    478.512054
# 16    429.803497
# 17    358.523926
# 18    419.875122
# 19    403.007568
# Name: 캠벨얼리_가격(원/kg), dtype: float64
# Epoch 1/200
# 1509/1509 [==============================] - 7s 5ms/step - loss: 0.0243 - val_loss: 0.0633
# Epoch 2/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0227 - val_loss: 0.0643
# Epoch 3/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0223 - val_loss: 0.0629
# Epoch 4/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0215 - val_loss: 0.0617
# Epoch 5/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0208 - val_loss: 0.0601
# Epoch 6/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0203 - val_loss: 0.0572
# Epoch 7/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0197 - val_loss: 0.0568
# Epoch 8/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0189 - val_loss: 0.0578
# Epoch 9/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0182 - val_loss: 0.0565
# Epoch 10/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0176 - val_loss: 0.0586
# Epoch 11/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0170 - val_loss: 0.0555
# Epoch 12/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0165 - val_loss: 0.0613
# Epoch 13/200
# 1509/1509 [==============================] - 7s 4ms/step - loss: 0.0158 - val_loss: 0.0559
# Epoch 00013: early stopping
# 샤인마스캇_가격(원/kg) 의 NMAE:  0.30676134705073843
# 0     4737.706543
# 1     4755.255859
# 2     4106.506348
# 3     4990.385742
# 4     4996.022949
# 5     3756.830566
# 6     3949.491211
# 7     3621.968750
# 8     3202.299561
# 9     -154.474167
# 10    -328.561554
# 11    -321.296722
# 12    2188.571533
# 13    2414.242432
# 14    2203.523682
# 15    2081.938232
# 16    2402.432373
# 17    1474.827393
# 18    1661.575317
# 19    1901.570923
# Name: 샤인마스캇_가격(원/kg), dtype: float64

# %%
submission.to_csv('result/02_LSTM.csv', index = False)

# %%
submission
# Out:
#                예측대상일자  배추_가격(원/kg)   무_가격(원/kg)  양파_가격(원/kg)  건고추_가격(원/kg)  \
# 0    2020-09-29+1week   390.230957   526.810974   631.129883   3848.074219
# 1    2020-09-29+2week   364.403931   747.890686   582.398682   3848.877930
# 2    2020-09-29+4week   342.680389   715.576111   593.250000   4945.966309
# 3    2020-09-30+1week   390.140594   868.790955   654.249512   4147.734863
# 4    2020-09-30+2week   364.481262  1095.748901   655.594482   4084.541016
# ..                ...          ...          ...          ...           ...
# 223  2021-11-03+2week     0.000000     0.000000     0.000000      0.000000
# 224  2021-11-03+4week     0.000000     0.000000     0.000000      0.000000
# 225  2021-11-04+1week     0.000000     0.000000     0.000000      0.000000
# 226  2021-11-04+2week     0.000000     0.000000     0.000000      0.000000
# 227  2021-11-04+4week     0.000000     0.000000     0.000000      0.000000
#
#      마늘_가격(원/kg)  대파_가격(원/kg)  얼갈이배추_가격(원/kg)  양배추_가격(원/kg)  깻잎_가격(원/kg)  ...  \
# 0    4546.910156  1825.984253      953.710022    667.464661  4931.467773  ...
# 1    5370.061523  1613.535889      924.436462    595.618408  4934.265625  ...
# 2    5339.697754  1349.367798      758.278259    521.538025  4993.927246  ...
# 3    4355.702148  1869.893311      941.699280    767.465576  4441.870117  ...
# 4    4864.045410  1578.052490      922.081299    675.718506  4643.827637  ...
# ..           ...          ...             ...           ...          ...  ...
# 223     0.000000     0.000000        0.000000      0.000000     0.000000  ...
# 224     0.000000     0.000000        0.000000      0.000000     0.000000  ...
# 225     0.000000     0.000000        0.000000      0.000000     0.000000  ...
# 226     0.000000     0.000000        0.000000      0.000000     0.000000  ...
# 227     0.000000     0.000000        0.000000      0.000000     0.000000  ...
#
#      당근_가격(원/kg)  파프리카_가격(원/kg)  새송이_가격(원/kg)  팽이버섯_가격(원/kg)  토마토_가격(원/kg)  \
# 0    1309.033203    3552.940918   1703.947266    2079.491699   2355.599121
# 1    1332.410156    3461.895508   1837.264648    1957.802490   2457.753662
# 2    1177.326904    3039.084961   1950.623047    1831.388672   3741.208984
# 3    1319.733521    2133.965820   1715.614136    2122.352051    526.637146
# 4    1384.297729    2170.050781   1878.565063    2017.009155   1753.656250
# ..           ...            ...           ...            ...           ...
# 223     0.000000       0.000000      0.000000       0.000000      0.000000
# 224     0.000000       0.000000      0.000000       0.000000      0.000000
# 225     0.000000       0.000000      0.000000       0.000000      0.000000
# 226     0.000000       0.000000      0.000000       0.000000      0.000000
# 227     0.000000       0.000000      0.000000       0.000000      0.000000
#
#      청상추_가격(원/kg)  백다다기_가격(원/kg)  애호박_가격(원/kg)  캠벨얼리_가격(원/kg)  샤인마스캇_가격(원/kg)
# 0     2645.181152     668.601929    625.835449     808.666138     4737.706543
# 1     2184.726807     794.578552    589.242493     630.522705     4755.255859
# 2     1896.309692     780.351074    557.865295     440.841919     4106.506348
# 3     2006.473633     755.671631    699.518616     815.783630     4990.385742
# 4     1883.904175     848.561768    662.040649     644.483154     4996.022949
# ..            ...            ...           ...            ...             ...
# 223      0.000000       0.000000      0.000000       0.000000        0.000000
# 224      0.000000       0.000000      0.000000       0.000000        0.000000
# 225      0.000000       0.000000      0.000000       0.000000        0.000000
# 226      0.000000       0.000000      0.000000       0.000000        0.000000
# 227      0.000000       0.000000      0.000000       0.000000        0.000000
#
# [228 rows x 22 columns]

# %% [markdown]
# - LSTM 품목별로 개별 예측해서 실험 결과 0.4507457824 나옴
# - 학습에 관여되는 값들이 추석 등이  큰 영향을 줄것으로 판단
